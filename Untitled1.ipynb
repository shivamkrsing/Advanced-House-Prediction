# %%
import pandas as pd
import numpy as np
df=pd.read_csv("bengaluru_house_data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df["availability"]=df["availability"].str[3:].astype(str)
df
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1                Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area   dy To Move               Uttarahalli      3 BHK
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area   dy To Move                  Kothanur      2 BHK
# ...                     ...          ...                       ...        ...
# 13315        Built-up  Area   dy To Move                Whitefield  5 Bedroom
# 13316  Super built-up  Area   dy To Move             Richards Town      4 BHK
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area          Jun           Padmanabhanagar      4 BHK
# 13319  Super built-up  Area   dy To Move              Doddathoguru      1 BHK
#
# ...

# %%
df1=df.dropna(subset=["location"])

# %%
df1.isna().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
location_count=df1["location"].value_counts()
location_count
# Out:
# Whitefield                                  540
# Sarjapur  Road                              399
# Electronic City                             302
# Kanakpura Road                              273
# Thanisandra                                 234
#                                            ...
# Adugodi                                       1
# Brigade Road                                  1
# Ramaswamy Palya - Kammanahalli Main Road      1
#  Basavangudi                                  1
# Gopal Reddy Layout                            1
# Name: location, Length: 1305, dtype: int64

# %%
len(location_count[location_count<=10])
# Out:
# 1064

# %%
len(location_count[location_count>10])
# Out:
# 241

# %%
df1["location"].nunique()
# Out:
# 1305

# %%
df1.shape
# Out:
# (13319, 9)

# %%
df1["location"]=df1["location"].apply(lambda x :x if x in location_count[location_count>10] else "other")
# Out:
# <ipython-input-261-041aeb30b4cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["location"]=df1["location"].apply(lambda x :x if x in location_count[location_count>10] else "other")

# %%
df1["location"].nunique()
# Out:
# 242

# %%
df1
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1                Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area   dy To Move               Uttarahalli      3 BHK
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area   dy To Move                  Kothanur      2 BHK
# ...                     ...          ...                       ...        ...
# 13315        Built-up  Area   dy To Move                Whitefield  5 Bedroom
# 13316  Super built-up  Area   dy To Move                     other      4 BHK
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area          Jun           Padmanabhanagar      4 BHK
# 13319  Super built-up  Area   dy To Move              Doddathoguru      1 BHK
#
# ...

# %%
df1["size"].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df1["size"].value_counts()
# Out:
# 2 BHK         5199
# 3 BHK         4309
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 Bedroom       2
# 10 BHK           2
# 11 BHK           2
# 12 Bedroom       1
# 16 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# 14 BHK           1
# 43 Bedroom       1
# 13 BHK           1
# 27 BHK           1
# Name: size, dtype: int64

# %%
df1.isna().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df1[df1["size"].isna()]
# Out:
#         area_type       availability        location size  society  \
# 579    Plot  Area  ediate Possession  Sarjapur  Road  NaN  Asiss B
# 1775   Plot  Area  ediate Possession           other  NaN  Orana N
# 2264   Plot  Area  ediate Possession    Banashankari  NaN      NaN
# 2809   Plot  Area  ediate Possession  Sarjapur  Road  NaN  AsdiaAr
# 2862   Plot  Area  ediate Possession     Devanahalli  NaN  Ajleyor
# 5333   Plot  Area  ediate Possession     Devanahalli  NaN  Emngs S
# 6423   Plot  Area  ediate Possession      Whitefield  NaN  SRniaGa
# 6636   Plot  Area  ediate Possession          Jigani  NaN  S2enste
# 6719   Plot  Area  ediate Possession         Hoskote  NaN  SJowsn
# 7680   Plot  Area  ediate Possession    Kasavanhalli  NaN      NaN
# 8306   Plot  Area  ediate Possession          Anekal  NaN  Vaensnd
# 8565   Plot  Area  ediate Possession           other  NaN  Ocezes
# 8703   Plot  Area  ediate Possession     Mysore Road  NaN  Naoden
# ...

# %%
df2=df1.dropna(subset=["size"])
df2.isna().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size               0
# society         5499
# total_sqft         0
# bath              57
# balcony          593
# price              0
# dtype: int64

# %%
df2.shape
# Out:
# (13303, 9)

# %%
society_count=df2["society"].value_counts()
society_count
# Out:
# GrrvaGr    80
# PrarePa    76
# Prtates    59
# Sryalan    59
# GMown E    56
#            ..
# Thowsil     1
# Cotaror     1
# Srrlsnu     1
# Vangsld     1
# Ciris P     1
# Name: society, Length: 2676, dtype: int64

# %%
len(society_count[society_count<=3])
# Out:
# 2213

# %%
len(society_count[society_count>3])
# Out:
# 463

# %%
df2["society"]=df2["society"].apply(lambda x : x if x in society_count[society_count>3] else "other")
df2
# Out:
# <ipython-input-273-7eee36f76229>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["society"]=df2["society"].apply(lambda x : x if x in society_count[society_count>3] else "other")
#                   area_type availability                  location       size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1                Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area   dy To Move               Uttarahalli      3 BHK
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area   dy To Move                  Kothanur      2 BHK
# ...

# %%
df2["society"].nunique()
# Out:
# 464

# %%
df2[df2["bath"].isna()]
# Out:
#                   area_type availability                  location       size  \
# 56           Built-up  Area          Feb               Devanahalli  4 Bedroom
# 81           Built-up  Area          Oct               Hennur Road  4 Bedroom
# 224    Super built-up  Area          Dec               Devanahalli      3 BHK
# 344    Super built-up  Area          Dec            Kanakpura Road      1 BHK
# 669    Super built-up  Area          Dec                  JP Nagar      5 BHK
# 702    Super built-up  Area          Dec                  JP Nagar      5 BHK
# 801    Super built-up  Area          Dec                  JP Nagar      4 BHK
# 941    Super built-up  Area   dy To Move                Whitefield  4 Bedroom
# 1264         Built-up  Area          May                    Hennur  3 Bedroom
# 1267   Super built-up  Area          Jun                 Yelahanka      3 BHK
# 1686   Super built-up  Area          Dec                Whitefield      1 BHK
# ...

# %%
df3=df2.dropna(subset=["bath"])

# %%
df3.shape
# Out:
# (13246, 9)

# %%
df3.isna().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# society           0
# total_sqft        0
# bath              0
# balcony         536
# price             0
# dtype: int64

# %%
df3["size"]=df3["size"].apply(lambda x : int(x.split(' ')[0]) )
df3
# Out:
# <ipython-input-279-d1c476d2399c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["size"]=df3["size"].apply(lambda x : int(x.split(' ')[0]) )
#                   area_type availability                  location  size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II     2
# 1                Plot  Area   dy To Move          Chikka Tirupathi     4
# 2            Built-up  Area   dy To Move               Uttarahalli     3
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli     3
# 4      Super built-up  Area   dy To Move                  Kothanur     2
# ...                     ...          ...                       ...   ...
# ...

# %%
df3[df3["balcony"].isna()]
# Out:
#                   area_type availability          location  size  society  \
# 6      Super built-up  Area          May  Old Airport Road     4  Jaades
# 7      Super built-up  Area   dy To Move      Rajaji Nagar     4  Brway G
# 9                Plot  Area   dy To Move             other     6    other
# 34           Built-up  Area   dy To Move     Kasturi Nagar     3    other
# 40           Built-up  Area   dy To Move     Murugeshpalya     2    other
# ...                     ...          ...               ...   ...      ...
# 13277            Plot  Area   dy To Move             other     7    other
# 13279            Plot  Area   dy To Move             other     6    other
# 13306            Plot  Area   dy To Move             other     4    other
# 13309  Super built-up  Area   dy To Move      Yeshwanthpur     3  IBityin
# 13316  Super built-up  Area   dy To Move             other     4    other
#
#       total_sqft  bath  balcony   price
# 6           2732   4.0      NaN  204.00
# ...

# %%
df3["balcony"].unique()
# Out:
# array([ 1.,  3., nan,  2.,  0.])

# %%
df3["balcony"].value_counts()
# Out:
# 2.0    5112
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: balcony, dtype: int64

# %%
df3["balcony"]=df3["balcony"].fillna(1)
# Out:
# <ipython-input-283-b04aecf6d9b5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["balcony"]=df3["balcony"].fillna(1)

# %%
df3.isna().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df3["total_sqft"].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
df.shape[0]-df3.shape[0]
# Out:
# 74

# %%
df3.shape
# Out:
# (13246, 9)

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
df4 = df3.copy()
df4.total_sqft = df4.total_sqft.apply(convert_sqft_to_num)
df4 = df4[df4.total_sqft.notnull()]
df4.head(2)
# Out:
#               area_type availability                  location  size  society  \
# 0  Super built-up  Area          Dec  Electronic City Phase II     2  Coomee
# 1            Plot  Area   dy To Move          Chikka Tirupathi     4  Theanmp
#
#    total_sqft  bath  balcony   price
# 0      1056.0   2.0      1.0   39.07
# 1      2600.0   5.0      3.0  120.00

# %%
df4.shape
# Out:
# (13200, 9)

# %%
df4["price"]=df4["price"]*100000/df4["total_sqft"]
df4
# Out:
#                   area_type availability                  location  size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II     2
# 1                Plot  Area   dy To Move          Chikka Tirupathi     4
# 2            Built-up  Area   dy To Move               Uttarahalli     3
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli     3
# 4      Super built-up  Area   dy To Move                  Kothanur     2
# ...                     ...          ...                       ...   ...
# 13315        Built-up  Area   dy To Move                Whitefield     5
# 13316  Super built-up  Area   dy To Move                     other     4
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar     2
# 13318  Super built-up  Area          Jun           Padmanabhanagar     4
# 13319  Super built-up  Area   dy To Move              Doddathoguru     1
#
#        society  total_sqft  bath  balcony         price
# ...

# %%
df4["price"]=df4["price"].astype(int)

# %%
df4
# Out:
#                   area_type availability                  location  size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II     2
# 1                Plot  Area   dy To Move          Chikka Tirupathi     4
# 2            Built-up  Area   dy To Move               Uttarahalli     3
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli     3
# 4      Super built-up  Area   dy To Move                  Kothanur     2
# ...                     ...          ...                       ...   ...
# 13315        Built-up  Area   dy To Move                Whitefield     5
# 13316  Super built-up  Area   dy To Move                     other     4
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar     2
# 13318  Super built-up  Area          Jun           Padmanabhanagar     4
# 13319  Super built-up  Area   dy To Move              Doddathoguru     1
#
#        society  total_sqft  bath  balcony  price
# ...

# %%
lowerlimit,upperlimit=df4["price"].quantile([0.05,0.90])
upperlimit
# Out:
# 11666.0

# %%
df5=df4[(df4["price"]>lowerlimit)&(df4["price"]<upperlimit)]
df5
# Out:
#                   area_type availability                  location  size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II     2
# 1                Plot  Area   dy To Move          Chikka Tirupathi     4
# 2            Built-up  Area   dy To Move               Uttarahalli     3
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli     3
# 4      Super built-up  Area   dy To Move                  Kothanur     2
# ...                     ...          ...                       ...   ...
# 13314  Super built-up  Area   dy To Move         Green Glen Layout     3
# 13315        Built-up  Area   dy To Move                Whitefield     5
# 13316  Super built-up  Area   dy To Move                     other     4
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar     2
# 13318  Super built-up  Area          Jun           Padmanabhanagar     4
#
#        society  total_sqft  bath  balcony  price
# ...

# %%
df5["balcony"].unique()
# Out:
# array([1., 3., 2., 0.])

# %%
df5["size"].unique()
# Out:
# array([ 2,  4,  3,  1,  6,  8,  5,  7, 11,  9, 10, 16, 14, 13],
#       dtype=int64)

# %%
df5["price"].describe()
# Out:
# count    11218.000000
# mean      5712.153147
# std       1838.472108
# min       3108.000000
# 25%       4320.000000
# 50%       5294.000000
# 75%       6666.000000
# max      11648.000000
# Name: price, dtype: float64

# %%
df5["size"].unique()
# Out:
# array([ 2,  4,  3,  1,  6,  8,  5,  7, 11,  9, 10, 16, 14, 13],
#       dtype=int64)

# %%
df5["balcony"].unique()
# Out:
# array([1., 3., 2., 0.])

# %%
i=df5[(df5['size']==1) & (df5["balcony"]>1)].index
i
# Out:
# Int64Index([  178,   582,   643,   816,  1446,  1822,  1964,  2007,  2156,
#              2775,  3497,  3666,  4758,  5221,  5573,  6366,  7107,  7908,
#              8027,  8036,  8111,  8571,  9918,  9947, 11706, 12081, 12471,
#             12506, 12587, 12604],
#            dtype='int64')

# %%
df6=df5.drop(i)

# %%
t=df6[(df6['size']==1) & (df6["bath"]>1)].index
t
# Out:
# Int64Index([  504,   526,  2036,  3170,  3944,  5220,  5922,  6339,  6717,
#              7070,  7826,  8073,  8149,  8251,  8533,  8657,  8810,  8948,
#              9047,  9575, 10175, 10221, 10504, 11413, 12699],
#            dtype='int64')

# %%
df6=df6.drop(t)

# %%
q=df6[(df6['size']==2) & (df6["bath"]>3)].index
df6=df6.drop(q)

# %%
a=df6[(df6['size']==3) & (df6["bath"]>4)].index
df6=df6.drop(a)

# %%
b=df6[(df6['size']==4) & (df6["bath"]>5)].index
df6=df6.drop(b)

# %%
c=df6[(df6['size']==5) & (df6["bath"]>6)].index
df6=df6.drop(c)

# %%
d=df6[(df6['size']==6) & (df6["bath"]>7)].index
df6=df6.drop(d)

# %%
e=df6[(df6['size']==7) & (df6["bath"]>8)].index
df6=df6.drop(e)

# %%
f=df6[(df6['size']==8) & (df6["bath"]>9)].index
df6=df6.drop(f)

# %%
g=df6[(df6['size']==10) & (df6["bath"]>11)].index
df6=df6.drop(g)

# %%
h=df6[(df6['size']==8) & (df6["bath"]<5)].index
df6=df6.drop(h)

# %%
j=df6[(df6['size']==4) & (df6["bath"]<2)].index
df6=df6.drop(j)

# %%
k=df6[(df6['size']==3) & (df6["bath"]<2)].index
df6=df6.drop(k)

# %%
df6.shape
# Out:
# (11050, 9)

# %%
df5.shape
# Out:
# (11218, 9)

# %%
df6
# Out:
#                   area_type availability                  location  size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II     2
# 1                Plot  Area   dy To Move          Chikka Tirupathi     4
# 2            Built-up  Area   dy To Move               Uttarahalli     3
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli     3
# 4      Super built-up  Area   dy To Move                  Kothanur     2
# ...                     ...          ...                       ...   ...
# 13314  Super built-up  Area   dy To Move         Green Glen Layout     3
# 13315        Built-up  Area   dy To Move                Whitefield     5
# 13316  Super built-up  Area   dy To Move                     other     4
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar     2
# 13318  Super built-up  Area          Jun           Padmanabhanagar     4
#
#        society  total_sqft  bath  balcony  price
# ...

# %% [markdown]
# # Error in total_sqft per bhk

# %%
df6[df6["size"]>11]
# Out:
#                  area_type availability location  size society  total_sqft  \
# 3609  Super built-up  Area   dy To Move    other    16   other     10000.0
# 4916  Super built-up  Area   dy To Move    other    14   other      1250.0
# 9935  Super built-up  Area   dy To Move    other    13   other      5425.0
#
#       bath  balcony  price
# 3609  16.0      1.0   5500
# 4916  15.0      0.0  10000
# 9935  13.0      0.0   5069

# %%
df6.shape
# Out:
# (11050, 9)

# %%
df6[df6["total_sqft"]/df6["size"]<300]
# Out:
#                   area_type availability          location  size society  \
# 58               Plot  Area   dy To Move     Murugeshpalya     6   other
# 68               Plot  Area   dy To Move             other     8   other
# 78           Built-up  Area   dy To Move  Kaval Byrasandra     2   other
# 119              Plot  Area   dy To Move       Hennur Road     2   other
# 170    Super built-up  Area   dy To Move             other     6   other
# ...                     ...          ...               ...   ...     ...
# 13217            Plot  Area   dy To Move             other     6   other
# 13221            Plot  Area   dy To Move             other     9   other
# 13279            Plot  Area   dy To Move             other     6   other
# 13281            Plot  Area   dy To Move   Margondanahalli     5   other
# 13303            Plot  Area   dy To Move    Vidyaranyapura     5   other
#
#        total_sqft  bath  balcony  price
# 58         1407.0   4.0      1.0  10660
# ...

# %%
i=df6[df6["total_sqft"]/df6["size"]<300].index
df6=df6.drop(i)
df6.shape
# Out:
# (10764, 9)

# %%
df6["price"].describe()
# Out:
# count    10764.000000
# mean      5617.708937
# std       1757.771701
# min       3108.000000
# 25%       4289.750000
# 50%       5236.500000
# 75%       6546.500000
# max      11648.000000
# Name: price, dtype: float64

# %%
import numpy as np
def remove_pps_outlier(df):
    df_out=pd.DataFrame()
    for key,subdf in df.groupby("location"):
        m=np.mean(subdf["price"])
        st=np.std(subdf["price"])
        reduced_df=subdf[(subdf["price"]>(m-st))&(subdf["price"]<(m+st))]
        df_out=pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df7=df6.copy()
df7=remove_pps_outlier(df6)
df7.shape
# Out:
# (7846, 9)

# %%
df7["size"].value_counts()
# Out:
# 2     3851
# 3     3123
# 4      438
# 1      321
# 5       54
# 6       31
# 7       11
# 8       10
# 9        4
# 11       1
# 13       1
# 16       1
# Name: size, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
def plot_scatter_chart(df,location):
    bhk2 = df[(df.location==location) & (df["size"]==2)]
    bhk3 = df[(df.location==location) & (df["size"]==3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.total_sqft,bhk2.price,color='blue',label='2 BHK', s=50)
    plt.scatter(bhk3.total_sqft,bhk3.price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()
    
plot_scatter_chart(df7,"Rajaji Nagar")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df7["le_area_type"]=le.fit_transform(df7["area_type"])
df7["le_availaility"]=le.fit_transform(df7["availability"])
df7["le_location"]=le.fit_transform(df7["location"])
df7["le_society"]=le.fit_transform(df7["society"])

# %%
df7.head(2)
# Out:
#               area_type availability              location  size society  \
# 0  Super built-up  Area          May   Devarachikkanahalli     3   other
# 1  Super built-up  Area   dy To Move   Devarachikkanahalli     2   other
#
#    total_sqft  bath  balcony  price  le_area_type  le_availaility  \
# 0      1250.0   2.0      3.0   3520             3               8
# 1      1170.0   2.0      2.0   3418             3              12
#
#    le_location  le_society
# 0            0         390
# 1            0         390

# %%
df7=df7.drop(["area_type","availability","location","society"],axis="columns")
df7
# Out:
#       size  total_sqft  bath  balcony  price  le_area_type  le_availaility  \
# 0        3      1250.0   2.0      3.0   3520             3               8
# 1        2      1170.0   2.0      2.0   3418             3              12
# 2        3      1425.0   2.0      2.0   4561             3              12
# 3        2       947.0   2.0      2.0   4540             3              12
# 4        2      1230.0   2.0      1.0   4715             3              12
# ...    ...         ...   ...      ...    ...           ...             ...
# 7841     2      1200.0   2.0      3.0   5833             1               4
# 7842     2      1095.0   2.0      1.0   5205             3              12
# 7843     2      1256.0   2.0      1.0   5175             0              12
# 7844     3      1440.0   2.0      2.0   4439             3               5
# 7845     2      1075.0   2.0      2.0   4465             3              12
#
#       le_location  le_society
# 0               0         390
# ...

# %%
X=df7.drop(["price","le_society","le_availaility","le_area_type"],axis="columns")
y=df7.price
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-331-b6ffe511f364> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 model=RandomForestClassifier()
# ----> 3 model.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
# ...

# %%
from sklearn.linear_model import LogisticRegression
reg=LogisticRegression()
reg.fit(x_train,y_train)

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(criterion="entropy")
tree.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-156-40b54c1d8166> in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 tree=DecisionTreeClassifier(criterion="entropy")
# ----> 3 tree.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
# ...
