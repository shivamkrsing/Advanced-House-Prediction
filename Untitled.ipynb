# %%
import pandas as pd
import numpy as np
df=pd.read_csv("bengaluru_house_data.csv")
df.head(10)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 6  Super built-up  Area         18-May          Old Airport Road      4 BHK
# 7  Super built-up  Area  Ready To Move              Rajaji Nagar      4 BHK
# 8  Super built-up  Area  Ready To Move              Marathahalli      3 BHK
# 9            Plot  Area  Ready To Move              Gandhi Bazar  6 Bedroom
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00
# 5  DuenaTa       1170   2.0      1.0   38.00
# 6  Jaades        2732   4.0      NaN  204.00
# 7  Brway G       3300   4.0      NaN  600.00
# 8      NaN       1310   3.0      1.0   63.25
# 9      NaN       1020   6.0      NaN  370.00

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.shape
# Out:
# (13320, 9)

# %%
df["availability"]=df["availability"].str[3:].astype(str)
df.head(3)
# Out:
#               area_type availability                  location       size  \
# 0  Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area   dy To Move               Uttarahalli      3 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00

# %%
society_count=df["society"].value_counts()
society_count
# Out:
# GrrvaGr    80
# PrarePa    76
# Prtates    59
# Sryalan    59
# GMown E    56
#            ..
# Bhncyis     1
# Siacen      1
# LiaveEn     1
# DSncele     1
# Toeadp      1
# Name: society, Length: 2688, dtype: int64

# %%
len(society_count[society_count>3])
# Out:
# 463

# %%
df["society"]=df["society"].apply(lambda x : x if x in society_count[society_count>3] else "other")
df
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1                Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area   dy To Move               Uttarahalli      3 BHK
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area   dy To Move                  Kothanur      2 BHK
# ...                     ...          ...                       ...        ...
# 13315        Built-up  Area   dy To Move                Whitefield  5 Bedroom
# 13316  Super built-up  Area   dy To Move             Richards Town      4 BHK
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area          Jun           Padmanabhanagar      4 BHK
# 13319  Super built-up  Area   dy To Move              Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony   price
# 0      Coomee        1056   2.0      1.0   39.07
# 1      Theanmp       2600   5.0      3.0  120.00
# 2        other       1440   2.0      3.0   62.00
# 3      Soiewre       1521   3.0      1.0   95.00
# 4        other       1200   2.0      1.0   51.00
# ...        ...        ...   ...      ...     ...
# 13315  ArsiaEx       3453   4.0      0.0  231.00
# 13316    other       3600   5.0      NaN  400.00
# 13317    other       1141   2.0      1.0   60.00
# 13318    other       4689   4.0      1.0  488.00
# 13319    other        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# society           0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %%
df[df["bath"].isna()]
# Out:
#                   area_type       availability        location       size  \
# 56           Built-up  Area                Feb     Devanahalli  4 Bedroom
# 81           Built-up  Area                Oct     Hennur Road  4 Bedroom
# 224    Super built-up  Area                Dec     Devanahalli      3 BHK
# 344    Super built-up  Area                Dec  Kanakpura Road      1 BHK
# 579              Plot  Area  ediate Possession  Sarjapur  Road        NaN
# ...                     ...                ...             ...        ...
# 11496  Super built-up  Area                Dec  Kanakpura Road      1 BHK
# 11569            Plot  Area  ediate Possession      Hosur Road        NaN
# 12768        Built-up  Area                Mar    Bettahalsoor  5 Bedroom
# 12861  Super built-up  Area                Dec        KR Puram      4 BHK
# 13240  Super built-up  Area         dy To Move     Devanahalli      1 BHK
#
#        society   total_sqft  bath  balcony    price
# 56       other  3010 - 3410   NaN      NaN  192.000
# 81       other  2957 - 3450   NaN      NaN  224.500
# 224    Jurdsig  1520 - 1740   NaN      NaN   74.820
# 344    PrarePa          525   NaN      NaN   21.530
# 579      other  1200 - 2400   NaN      NaN   34.185
# ...        ...          ...   ...      ...      ...
# 11496  PrarePa          525   NaN      NaN   27.000
# 11569    other         1350   NaN      NaN    8.440
# 12768    other         3210   NaN      NaN  353.000
# 12861    other  2204 - 2362   NaN      NaN  121.000
# 13240    other  1020 - 1130   NaN      NaN   52.570
#
# [73 rows x 9 columns]

# %%
df1=df[~(df["bath"].isna())]
df1.shape
# Out:
# (13247, 9)

# %%
df1.isna().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size              0
# society           0
# total_sqft        0
# bath              0
# balcony         536
# price             0
# dtype: int64

# %%
df2=df1.drop("balcony",axis="columns")
df2=df1.dropna()
df2.shape
# Out:
# (12710, 9)

# %%
df2.head(5)
# Out:
#               area_type availability                  location       size  \
# 0  Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area   dy To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area   dy To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area   dy To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2    other       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4    other       1200   2.0      1.0   51.00

# %%
df2["bhk"]=df2["size"].apply(lambda x : int(x.split(' ')[0]))
# Out:
# <ipython-input-138-2866e0a2fcbb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["bhk"]=df2["size"].apply(lambda x : int(x.split(' ')[0]))

# %%
df2.location.unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
location_count=df2["location"].value_counts()
location_count
# Out:
# Whitefield                514
# Sarjapur  Road            372
# Electronic City           300
# Kanakpura Road            261
# Thanisandra               231
#                          ...
# NR Colony                   1
# Chikkagubbi                 1
# Ramanagara Channapatna      1
# t.c palya                   1
# Yelahanka,MVIT college      1
# Name: location, Length: 1265, dtype: int64

# %%
df2.location=df2["location"].apply(lambda x : x if x in location_count[location_count>10] else "OTHER")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df2.location.nunique()
# Out:
# 238

# %%
df2
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1                Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area   dy To Move               Uttarahalli      3 BHK
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area   dy To Move                  Kothanur      2 BHK
# ...                     ...          ...                       ...        ...
# 13314  Super built-up  Area   dy To Move         Green Glen Layout      3 BHK
# 13315        Built-up  Area   dy To Move                Whitefield  5 Bedroom
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area          Jun           Padmanabhanagar      4 BHK
# 13319  Super built-up  Area   dy To Move              Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony   price  bhk
# 0      Coomee        1056   2.0      1.0   39.07    2
# 1      Theanmp       2600   5.0      3.0  120.00    4
# 2        other       1440   2.0      3.0   62.00    3
# 3      Soiewre       1521   3.0      1.0   95.00    3
# 4        other       1200   2.0      1.0   51.00    2
# ...        ...        ...   ...      ...     ...  ...
# 13314  SoosePr       1715   3.0      3.0  112.00    3
# 13315  ArsiaEx       3453   4.0      0.0  231.00    5
# 13317    other       1141   2.0      1.0   60.00    2
# 13318    other       4689   4.0      1.0  488.00    4
# 13319    other        550   1.0      1.0   17.00    1
#
# [12710 rows x 10 columns]

# %%
df2.shape
# Out:
# (12710, 10)

# %%
df2.isna().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# bhk             0
# dtype: int64

# %%
df2["total_sqft"].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def is_float(x):
    try:
        float(x)
    except:
         return False
    return True

# %%
df2[~(df2["total_sqft"].apply(is_float))]
# Out:
#                   area_type availability            location   size  society  \
# 30     Super built-up  Area          Dec           Yelahanka  4 BHK  LedorSa
# 122    Super built-up  Area          Mar              Hebbal  4 BHK  SNontle
# 137    Super built-up  Area          Mar  8th Phase JP Nagar  2 BHK  Vaarech
# 165    Super built-up  Area          Dec            Sarjapur  2 BHK    other
# 188    Super built-up  Area   dy To Move            KR Puram  2 BHK    other
# ...                     ...          ...                 ...    ...      ...
# 12975  Super built-up  Area          Aug          Whitefield  2 BHK    other
# 12990  Super built-up  Area          May      Talaghattapura  3 BHK  Sodgere
# 13059  Super built-up  Area   dy To Move              Harlur  2 BHK  Shodsir
# 13265  Super built-up  Area          Sep               Hoodi  2 BHK    other
# 13299  Super built-up  Area          Dec          Whitefield  4 BHK  Prtates
#
#         total_sqft  bath  balcony    price  bhk
# 30     2100 - 2850   4.0      0.0  186.000    4
# 122    3067 - 8156   4.0      0.0  477.000    4
# 137    1042 - 1105   2.0      0.0   54.005    2
# 165    1145 - 1340   2.0      0.0   43.490    2
# 188    1015 - 1540   2.0      0.0   56.800    2
# ...            ...   ...      ...      ...  ...
# 12975   850 - 1060   2.0      0.0   38.190    2
# 12990  1804 - 2273   3.0      0.0  122.000    3
# 13059  1200 - 1470   2.0      0.0   72.760    2
# 13265  1133 - 1384   2.0      0.0   59.135    2
# 13299  2830 - 2882   5.0      0.0  154.500    4
#
# [186 rows x 10 columns]

# %%
def convert(x):
    tokens=x.split('-')
    if len(tokens)==2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
df2["total_sqft"]=df2["total_sqft"].apply(convert)
df2 = df2[df2.total_sqft.notnull()]
df2["total_sqft"].unique()
# Out:
# <ipython-input-150-868edd362782>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["total_sqft"]=df2["total_sqft"].apply(convert)
# array([1056. , 2600. , 1440. , ..., 1258.5,  774. , 4689. ])

# %%
df2.shape
# Out:
# (12668, 10)

# %%
df2
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1                Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area   dy To Move               Uttarahalli      3 BHK
# 3      Super built-up  Area   dy To Move        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area   dy To Move                  Kothanur      2 BHK
# ...                     ...          ...                       ...        ...
# 13314  Super built-up  Area   dy To Move         Green Glen Layout      3 BHK
# 13315        Built-up  Area   dy To Move                Whitefield  5 Bedroom
# 13317        Built-up  Area   dy To Move     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area          Jun           Padmanabhanagar      4 BHK
# 13319  Super built-up  Area   dy To Move              Doddathoguru      1 BHK
#
#        society  total_sqft  bath  balcony   price  bhk
# 0      Coomee       1056.0   2.0      1.0   39.07    2
# 1      Theanmp      2600.0   5.0      3.0  120.00    4
# 2        other      1440.0   2.0      3.0   62.00    3
# 3      Soiewre      1521.0   3.0      1.0   95.00    3
# 4        other      1200.0   2.0      1.0   51.00    2
# ...        ...         ...   ...      ...     ...  ...
# 13314  SoosePr      1715.0   3.0      3.0  112.00    3
# 13315  ArsiaEx      3453.0   4.0      0.0  231.00    5
# 13317    other      1141.0   2.0      1.0   60.00    2
# 13318    other      4689.0   4.0      1.0  488.00    4
# 13319    other       550.0   1.0      1.0   17.00    1
#
# [12668 rows x 10 columns]

# %%
df2["price_per_sqft"]=df2['price']*100000/df2["total_sqft"]
df2.head()
# Out:
# <ipython-input-153-6a2b5964fbc7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["price_per_sqft"]=df2['price']*100000/df2["total_sqft"]
#               area_type availability                  location       size  \
# 0  Super built-up  Area          Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area   dy To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area   dy To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area   dy To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area   dy To Move                  Kothanur      2 BHK
#
#    society  total_sqft  bath  balcony   price  bhk  price_per_sqft
# 0  Coomee       1056.0   2.0      1.0   39.07    2     3699.810606
# 1  Theanmp      2600.0   5.0      3.0  120.00    4     4615.384615
# 2    other      1440.0   2.0      3.0   62.00    3     4305.555556
# 3  Soiewre      1521.0   3.0      1.0   95.00    3     6245.890861
# 4    other      1200.0   2.0      1.0   51.00    2     4250.000000

# %%
df2[df2["total_sqft"]/df2.bhk<300]
# Out:
#             area_type availability          location       size society  \
# 58         Plot  Area   dy To Move     Murugeshpalya  6 Bedroom   other
# 68         Plot  Area   dy To Move             OTHER  8 Bedroom   other
# 70         Plot  Area   dy To Move             OTHER  3 Bedroom   other
# 78     Built-up  Area   dy To Move  Kaval Byrasandra      2 BHK   other
# 89         Plot  Area   dy To Move      Rajaji Nagar  6 Bedroom   other
# ...               ...          ...               ...        ...     ...
# 13219      Plot  Area   dy To Move           Laggere  7 Bedroom   other
# 13221      Plot  Area   dy To Move             OTHER  9 Bedroom   other
# 13281      Plot  Area   dy To Move   Margondanahalli  5 Bedroom   other
# 13303      Plot  Area   dy To Move    Vidyaranyapura  5 Bedroom   other
# 13311      Plot  Area   dy To Move  Ramamurthy Nagar  7 Bedroom   other
#
#        total_sqft  bath  balcony  price  bhk  price_per_sqft
# 58         1407.0   4.0      1.0  150.0    6    10660.980810
# 68         1350.0   7.0      0.0   85.0    8     6296.296296
# 70          500.0   3.0      2.0  100.0    3    20000.000000
# 78          460.0   1.0      0.0   22.0    2     4782.608696
# 89          710.0   6.0      3.0  160.0    6    22535.211268
# ...           ...   ...      ...    ...  ...             ...
# 13219      1590.0   9.0      3.0  132.0    7     8301.886792
# 13221      1178.0   9.0      1.0   75.0    9     6366.723260
# 13281      1375.0   5.0      1.0  125.0    5     9090.909091
# 13303       774.0   5.0      3.0   70.0    5     9043.927649
# 13311      1500.0   9.0      2.0  250.0    7    16666.666667
#
# [655 rows x 11 columns]

# %%
i=df2[df2["total_sqft"]/df2.bhk<300].index
i
# Out:
# Int64Index([   58,    68,    70,    78,    89,   119,   129,   170,   176,
#               193,
#             ...
#             13112, 13146, 13190, 13198, 13216, 13219, 13221, 13281, 13303,
#             13311],
#            dtype='int64', length=655)

# %%
df3=df2.drop(i)
df3.shape
# Out:
# (12013, 11)

# %%
df3["price_per_sqft"].describe()
# Out:
# count     12013.000000
# mean       6206.082347
# std        3985.518807
# min         267.829813
# 25%        4199.363057
# 50%        5252.525253
# 75%        6823.529412
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
def remove_pps_outlier(df):
    df_out=pd.DataFrame()
    for key,subdf in df.groupby("location"):
        m=np.mean(subdf["price_per_sqft"])
        st=np.std(subdf["price_per_sqft"])
        reduced_df=subdf[(subdf["price_per_sqft"]>(m-st))&(subdf["price_per_sqft"]<(m+st))]
        df_out=pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df4=df3.copy()
df4=remove_pps_outlier(df3)
df4.shape
# Out:
# (9849, 11)

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
def plot_scatter_chart(df,location):
    bhk2=df[(df["location"]==location)& (df.bhk==2) ]
    bhk3=df[(df["location"]==location)& (df.bhk==3) ]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.total_sqft,bhk2.price,color="blue",label="2 bhk",s=50)
    plt.scatter(bhk3.total_sqft,bhk3.price,marker='+',color="red",label="3 bhk",s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()

plot_scatter_chart(df4,"Rajaji Nagar")

# %%
plot_scatter_chart(df4,"Hebbal")

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df5 = remove_bhk_outliers(df4)

# %%
df5.shape
# Out:
# (7038, 11)

# %%
plot_scatter_chart(df5,"Rajaji Nagar")

# %%
plot_scatter_chart(df5,"Hebbal")

# %%
df6=df5[df5.bath<df5.bhk+2]
df6.shape
# Out:
# (6971, 11)

# %%
df7=df6.drop(["size","price_per_sqft"],axis="columns")
df7
# Out:
#                  area_type availability              location  society  \
# 1     Super built-up  Area   dy To Move   Devarachikkanahalli    other
# 2               Plot  Area   dy To Move   Devarachikkanahalli    other
# 3     Super built-up  Area   dy To Move   Devarachikkanahalli    other
# 4     Super built-up  Area   dy To Move   Devarachikkanahalli    other
# 5     Super built-up  Area   dy To Move   Devarachikkanahalli    other
# ...                    ...          ...                   ...      ...
# 9840  Super built-up  Area   dy To Move          Yeshwanthpur    other
# 9841  Super built-up  Area          Aug          Yeshwanthpur  Aroomba
# 9843        Built-up  Area   dy To Move          Yeshwanthpur    other
# 9847  Super built-up  Area   dy To Move          Yeshwanthpur  Goandn
# 9848  Super built-up  Area   dy To Move          Yeshwanthpur    other
#
#       total_sqft  bath  balcony  price  bhk
# 1         1250.0   2.0      2.0   40.0    2
# 2         1200.0   2.0      2.0   83.0    2
# 3         1170.0   2.0      2.0   40.0    2
# 4         1425.0   2.0      2.0   65.0    3
# 5          947.0   2.0      2.0   43.0    2
# ...          ...   ...      ...    ...  ...
# 9840      1195.0   2.0      2.0  100.0    2
# 9841      1692.0   3.0      3.0  108.0    3
# 9843      2500.0   5.0      2.0  185.0    6
# 9847      1855.0   3.0      3.0  135.0    3
# 9848      1876.0   3.0      3.0  160.0    3
#
# [6971 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df7["le_area_type"]=le.fit_transform(df7["area_type"])
df7["le_availaility"]=le.fit_transform(df7["availability"])
df7["le_location"]=le.fit_transform(df7["location"])
df7["le_society"]=le.fit_transform(df7["society"])

# %%
df7.head(2)
# Out:
#               area_type availability              location society  \
# 1  Super built-up  Area   dy To Move   Devarachikkanahalli   other
# 2            Plot  Area   dy To Move   Devarachikkanahalli   other
#
#    total_sqft  bath  balcony  price  bhk  le_area_type  le_availaility  \
# 1      1250.0   2.0      2.0   40.0    2             3              12
# 2      1200.0   2.0      2.0   83.0    2             2              12
#
#    le_location  le_society
# 1            0         397
# 2            0         397

# %%
df7=df7.drop(["area_type","availability","location","society"],axis="columns")
df7
# Out:
#       total_sqft  bath  balcony  price  bhk  le_area_type  le_availaility  \
# 1         1250.0   2.0      2.0   40.0    2             3              12
# 2         1200.0   2.0      2.0   83.0    2             2              12
# 3         1170.0   2.0      2.0   40.0    2             3              12
# 4         1425.0   2.0      2.0   65.0    3             3              12
# 5          947.0   2.0      2.0   43.0    2             3              12
# ...          ...   ...      ...    ...  ...           ...             ...
# 9840      1195.0   2.0      2.0  100.0    2             3              12
# 9841      1692.0   3.0      3.0  108.0    3             3               1
# 9843      2500.0   5.0      2.0  185.0    6             0              12
# 9847      1855.0   3.0      3.0  135.0    3             3              12
# 9848      1876.0   3.0      3.0  160.0    3             3              12
#
#       le_location  le_society
# 1               0         397
# 2               0         397
# 3               0         397
# 4               0         397
# 5               0         397
# ...           ...         ...
# 9840          237         397
# 9841          237          18
# 9843          237         397
# 9847          237         100
# 9848          237         397
#
# [6971 rows x 9 columns]

# %%
X=df7.drop(["price","le_society","le_availaility","le_area_type"],axis="columns")
y=df7.price.astype(int)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(x_train,y_train)
lr_clf.score(x_test,y_test)
# Out:
# 0.6593473173841764

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-172-597cd0bed9a6> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 model=RandomForestClassifier()
# ----> 3 model.fit(x_train,y_train)
#       4 model.score(x_test,y_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     888         """
#     889
# --> 890         super().fit(
#     891             X, y,
#     892             sample_weight=sample_weight,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._add_node()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._resize_c()
#
# sklearn\tree\_utils.pyx in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 20119552 bytes

# %%
from sklearn.linear_model import LogisticRegression
reg=LogisticRegression()
reg.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier(criterion="entropy")
tree.fit(x_train,y_train)

# %%
reg.score(x_test,y_test)
# Out:
# 0.030107526881720432

# %%
tree.
